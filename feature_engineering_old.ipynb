# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.preprocessing import OneHotEncoder

# %%
train_set = pd.read_csv('./dataset_diabetes/diabetic_data_train.csv')
ts = train_set.copy()
ts.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
for col in ts.columns:
    print(ts.groupby(col)[col].value_counts())
# Out:
# encounter_id  encounter_id
# 12522         12522           1
# 15738         15738           1
# 28236         28236           1
# 35754         35754           1
# 36900         36900           1
#                              ..
# 443847548     443847548       1
# 443847782     443847782       1
# 443854148     443854148       1
# 443857166     443857166       1
# 443867222     443867222       1
# Name: encounter_id, Length: 81412, dtype: int64
# patient_nbr  patient_nbr
# 135          135            2
# 729          729            1
# 927          927            1
# 1152         1152           4
# 1305         1305           1
#                            ..
# 189351095    189351095      1
# 189365864    189365864      1
# 189445127    189445127      1
# 189481478    189481478      1
# 189502619    189502619      1
# Name: patient_nbr, Length: 60044, dtype: int64
# race             race
# ?                ?                   1800
# AfricanAmerican  AfricanAmerican    15384
# ...
