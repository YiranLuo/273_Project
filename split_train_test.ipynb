# %%
# import libraries
import os
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# read in dataset and split it to 80% training data and 20% testing data
diabetes = pd.read_csv('./dataset_diabetes/diabetic_data_clean.csv')
train_set, test_set = train_test_split(diabetes, test_size = 0.2)

# %%
train_set.head(10)
# Out:
#                   race  gender  age  admission_type_id  \
# 10245  AfricanAmerican       0   85                  1
# 741    AfricanAmerican       0   25                  1
# 17931        Caucasian       1   55                  6
# 26355        Caucasian       0   85                  2
# 43278  AfricanAmerican       1   65                  3
# 50209        Caucasian       0   75                  3
# 53929        Caucasian       1   85                  3
# 52436        Caucasian       0   55                  1
# 16586        Caucasian       0   55                  3
# 58616  AfricanAmerican       1   85                  1
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# 10245                        18                    7                 2
# 741                           1                    7                 3
# 17931                        25                   17                 1
# 26355                         1                    1                 5
# ...

# %%
train_set.shape
# Out:
# (57214, 29)

# %%
test_set.shape
# Out:
# (14304, 29)

# %%
# save splited data to files
train_set.to_csv('./dataset_diabetes/diabetic_data_train.csv', index = False)
test_set.to_csv('./dataset_diabetes/diabetic_data_test.csv', index = False)

# %%
train_saved = pd.read_csv('./dataset_diabetes/diabetic_data_train.csv')
train_saved.shape
# Out:
# (57214, 29)
