# %%
# import libraries
import os
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# read in dataset and split it to 80% training data and 20% testing data
diabetes = pd.read_csv('./dataset_diabetes/diabetic_data.csv')
train_set, test_set = train_test_split(diabetes, test_size = 0.2)

# %%
train_set.head(10)
# Out:
#        encounter_id  patient_nbr             race  gender      age weight  \
# 48910     148649250     97924023        Caucasian    Male  [70-80)      ?
# 82612     257580330     36437832        Caucasian  Female  [70-80)      ?
# 65400     182280804     41015475        Caucasian    Male  [60-70)      ?
# 49522     149778894     50829453  AfricanAmerican  Female  [80-90)      ?
# 95278     359701316    106421922        Caucasian    Male  [40-50)      ?
# 39376     122541804     24243804  AfricanAmerican  Female  [70-80)      ?
# 67551     189726546     44169111        Caucasian  Female  [50-60)      ?
# 69277     196711260     64791738        Caucasian  Female  [70-80)      ?
# 96549     376731818     67687461        Caucasian    Male  [60-70)      ?
# 85239     269875968     63799011        Caucasian    Male  [40-50)      ?
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 48910                  5                         2                    1
# 82612                  2                         3                    1
# 65400                  1                         1                    7
# 49522                  3                         6                    1
# 95278                  1                         1                    7
# 39376                  3                         1                    1
# 67551                  1                         1                    7
# 69277                  1                         1                    7
# 96549                  1                         1                    7
# 85239                  1                         1                    7
#
#        time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 48910                 1  ...          No  Steady                   No
# 82612                 1  ...          No  Steady                   No
# 65400                 2  ...          No      No                   No
# 49522                 2  ...          No  Steady                   No
# 95278                 3  ...          No      Up                   No
# 39376                 6  ...          No  Steady                   No
# 67551                 2  ...          No      No                   No
# 69277                 1  ...          No  Steady                   No
# 96549                 1  ...          No  Steady                   No
# 85239                 6  ...          No  Steady                   No
#
#        glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 48910                   No                        No                       No
# 82612                   No                        No                       No
# 65400                   No                        No                       No
# 49522                   No                        No                       No
# 95278                   No                        No                       No
# 39376                   No                        No                       No
# 67551                   No                        No                       No
# 69277                   No                        No                       No
# 96549                   No                        No                       No
# 85239                   No                        No                       No
#
#        metformin-pioglitazone  change diabetesMed readmitted
# 48910                      No      No         Yes        <30
# 82612                      No      No         Yes         NO
# 65400                      No      No          No        >30
# 49522                      No      Ch         Yes        >30
# 95278                      No      Ch         Yes         NO
# 39376                      No      Ch         Yes        >30
# 67551                      No      No         Yes        >30
# 69277                      No      Ch         Yes         NO
# 96549                      No      Ch         Yes        <30
# 85239                      No      Ch         Yes        >30
#
# [10 rows x 50 columns]

# %%
train_set.shape
# Out:
# (81412, 50)

# %%
test_set.shape
# Out:
# (20354, 50)

# %%
# save splited data to files
train_set.to_csv('./dataset_diabetes/diabetic_data_train.csv', index = False)
test_set.to_csv('./dataset_diabetes/diabetic_data_test.csv', index = False)

# %%
train_saved = pd.read_csv('./dataset_diabetes/diabetic_data_train.csv')
train_saved.shape
# Out:
# (81412, 50)
